# %% [markdown]
# <a href="https://colab.research.google.com/github/Padmapalita/Portfolio_Deep_Learning_CNN/blob/main/CIFAR10_Lotus_Model_CNN.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # CIFAR10 - Lotus Model CNN
#
# This notebook contains the Lotus model I developed for the CIFAR-10 images set according to a tailored specification from a deep learning researcher as part of my Masters Data Science and Artifical Intelligence.
#
# The notebook contains a few notes on the developmental milestones, and can be read along with the "CIFAR10 - Lotus Model.pdf" which summarises the project.
#
# ### This model achieved a final accuracy of 95.17%
#
# **Note: This notebook needs at least 40gb GPU and will take approximately 18 hours to train the model**
#
# Please import the my_utils.py into the environment in order for the notebook to run.

# %%
#Import libraries
import my_utils as mu
import torch
import torchvision
from torch import nn
from torch.nn import functional as F
from torchvision import transforms
from torch.utils import data

# %%
# Set up the GPU from pytorch cuda and confirm the device available
device = torch.device('cuda' if torch.cuda.is_available() else 'cpu') #choose device: cpu or gpu
print('Using device:', device)
if torch.cuda.is_available(): print(torch.cuda.get_device_name(0)) # print the type of the chosen gpu
# Out:
# Using device: cuda
# NVIDIA A100-SXM4-40GB

# %% [markdown]
# ## Section 1: Read the dataset and create dataloaders

# %% [markdown]
# During development I have experimented with a number of transformations and normalisation on the training set to prevent early overfitting.
#
# Transformations that are too extreme limit the maximum accuracy of the model training, while no transformation limits the number of epochs before the training accuracy diverts from the test accuracy.
#
# I have also experimented with CutMix transformations and managed to get a model working with https://github.com/ildoonet/cutmix However one of the disadvantages of cutmix is a lack of training accuracy calculation as the images are now a combination of two. (In the end this is not included in this notebook as it was not used to create the final model)
#
# The only code I have taken from other sources in this project (with the exception of my_utilities.py and inspiration from the VGG model) is the normalisation values taken from the D2l.ai chapter on the CIFAR set which is used in the code below.

# %%
# create the dataloaders
def get_dataloader_workers(): 
    """Use 4 processes to read the data."""
    return 4


def load_data_cifar_10(batch_size, resize=None):  
    """Download the CIFAR_10 dataset and then load it into memory.
    normalisation values taken from https://d2l.ai/chapter_computer-vision/kaggle-cifar10.html
    """
    # transfomrations used on the training set
    train_trans = [transforms.RandomResizedCrop(size=56, scale=(0.75, 1.0)),
                   transforms.RandomAffine(3), 
                   transforms.RandomHorizontalFlip(0.5), 
                   transforms.RandomVerticalFlip(0.1),
                   transforms.RandomRotation(45), 
                   transforms.RandomPerspective(0.15) ,
                   transforms.RandomGrayscale(p=0.05),
                   transforms.ColorJitter(brightness=0.25, contrast=0.25, saturation=0.25, hue=0.15,), 
                   transforms.ToTensor(),
                   transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010)) ]
    # normalisation used for the test set
    test_trans = [transforms.ToTensor(),
                  transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010)) ]

    if resize:
        train_trans.insert(0, transforms.Resize(resize))
        test_trans.insert(0, transforms.Resize(resize))

    train_trans = transforms.Compose(train_trans)
    test_trans = transforms.Compose(test_trans)
    torchvision.datasets.CIFAR10
    cifar_train = torchvision.datasets.CIFAR10(root="../data", train=True, transform=train_trans, download=True)
    cifar_test = torchvision.datasets.CIFAR10(root="../data", train=False, transform=test_trans, download=True)
    return (data.DataLoader(cifar_train, batch_size, shuffle=True,num_workers=get_dataloader_workers()),
            data.DataLoader(cifar_test, batch_size, shuffle=False,num_workers=get_dataloader_workers()))

# %%
# Load the train and test batches
batch_size = 196
resize = 56

train_iter, test_iter = load_data_cifar_10(batch_size, resize=resize)
# Out:
# Downloading https://www.cs.toronto.edu/~kriz/cifar-10-python.tar.gz to ../data/cifar-10-python.tar.gz
# 100%|██████████| 170498071/170498071 [00:13<00:00, 12947738.05it/s]
# Extracting ../data/cifar-10-python.tar.gz to ../data
# Files already downloaded and verified

# %% [markdown]
# ## Section 2: Create the model

# %% [markdown]
# ### Model development

# %% [markdown]
# The final model is the result of extensive experiments and adjustments. In this section, I walk you through the adjustments to the model however this does not include the training regime which is covered in section 3.
#
#
# Early versions used two stacked convolutional outputs combined with the vector A. This showed limited success but it did learn from the data.
#
#
# By increasing the number of convolutional outputs to five I was able to get a reasonable rate of learning from the model and decided to use VGG as the base inspiration for my experiments.
#
#
# This allows blocks to be repeated and uses a maxpool layer to half the feature map (while each block increases channels) however, I also built in a value for the number of convolutional outputs to be stacked, allowing for quicker experimentation.
#
#
# The first most basic model created like this was a 3 Block 5 convolutional stack with a single linear classifier. Accuracy 74.84%
#
#
# Further experiments showed that increasing the number of stacked convolutional outputs increased the rate at which the model learnt but did not dramatically improve accuracy.
# The optimal number of stacked convolutional outputs for my model is 10,
#
#
# Because a block reduces a feature map by half, this model is limited to 3 blocks when using the 32*32 image size.
#
#
# Experimentation with the final number of channels leaving the blocks showed that there was a huge computational load for 1024 and most experimentation was done with 512 channels until the final round, which is presented in this notebook.
#
#
# Thinking about the feature map and convolutional kernel size, I wanted to increase the receptive field.
#
#
# I decided to layer a second convolutional within each of the stacked convolutional outputs. This boosted the accuracy of the model by around 5%.
#
#
# A third convolutional layer within each of the stacked convolutional outputs boosted accuracy again by around 5%.
#
#
# This triple layer of conv2D->ReLU has a receptive field of 7x7 which limits the number of blocks that the model can run before the feature map becomes too small for this set-up.
#
#
# The final model resizes the original 32x32 image to 56x56 to allow a fourth block to work effectively.
#
#
# Finally, the addition of batch normalisation before the max-pooling within each block increased the speed at which the model learnt during training.
#
#
# During this process, I also experimented with the complexity of the classifier.
# In the end, I have used a 6-layer MLP which includes ReLU and Dropout.
#
#
# Many versions of the model achieved an accuracy of 85-92%. The final version of the model has achieve just over 95%
#
#
# The final accuracy is a combination of the transformations, model and training schedule. Demonstrating that deep learning is less of a science and more of an art.

# %% [markdown]
# ## The Lotus model
# The model consists of block repeating 4 times and a multilayer perception with 6 layers (4 hidden)
#
# The number of channels increases block by block
# - block 1: 3 channels in 96 channels out
# - block 2: 96 channels in 256 channels out
# - block 3: 256 channels in 512 channels out
# - black 4: 512 channels in 1024 channels out
#
# The models takes a resized image 52x52
# - Block 1: reduces the feature map to 28x28
# - Block 2: reduces the feature map to 14x14
# - Block 3: reduces the feature map to 7x7
# - Block 4: reduces the feature map to 3x3
#
# The repeating block uses the following operations.
# The batch X is processed by two seperate processes:
#
# **Process 1.** X is passed through AdaptiveAvgPool to produce 1 value per channel. This is then passed through a nn.linear model which outputs the same number of features out needed by process 2 nn.ReLu is used for a nonlinear transformation. The output of this process is called vector A.
#
# **Process 2.** X is passed into K number of convolutional layers. Each layer is seperate and passes X through a 3x3 conv kernel, a ReLU, a second 3x3 conv kernel, a second relu, a third 3x3 conv kernel, a third relu.
# Process 2 stacks K number of outputs together
#
# **Vector A and Stacked K Linear combination:**
# Stacked K is then flattened (start_dim=2) and torch.matmul is used to combined i-th element of vector A with the i-th convolutional output of stack K.  This is then reshaped back into a 4 dimensional Tensor (batchsize, output_channels, H, W)
#
# **Norm and maxpool:** Before the end of each block the  output (linear combination of Vactor A and Stack K) is processed by nn.batchNorm2D and NN.MaxPool2D

# %%
## This is the basic block
class Lotus_Block(nn.Module):
    def __init__(self, K_conv_layers, channels_in, output_channels, batch_size):
        super(Lotus_Block, self).__init__()
        self.batch_size = batch_size
        self.K_conv_layers = K_conv_layers
        self.channels_in = channels_in
        self.output_channels = output_channels

        # create the models elements
        self.Spatial = nn.AdaptiveAvgPool2d(output_size=1)
        self.Linear = nn.Linear(self.channels_in,self.K_conv_layers)
        self.NLactivation = nn.ReLU()
        self.flat2ndD = nn.Flatten(start_dim=2)

        # create elements for k number of convultional layers
        for i in range(self.K_conv_layers):
            self.add_module('conv{0}'.format(i), nn.Conv2d(self.channels_in, self.output_channels, kernel_size=3, padding=1, stride=1))
            self.input_channels = self.output_channels
            self.add_module('relu{0}'.format(i), nn.ReLU())
            self.add_module('conv2{0}'.format(i), nn.Conv2d(self.output_channels, self.output_channels, kernel_size=3, padding=1, stride=1))
            self.add_module('relu2{0}'.format(i), nn.ReLU())
            self.add_module('conv3{0}'.format(i), nn.Conv2d(self.output_channels, self.output_channels, kernel_size=3, padding=1, stride=1))
            self.add_module('relu3{0}'.format(i), nn.ReLU())

        self.batch = nn.BatchNorm2d(self.output_channels)
        self.max_pool = nn.MaxPool2d(kernel_size=2,stride=2)

    def forward(self, x):
        # manage the dimensions for reshapes and variable batchsize 
        self.input_dimensions = x.size()[3]
        self.batch_size = x.size()[0]
        #self.Spatial = nn.AdaptiveAvgPool2d(output_size=1)

        # PROCESS 1: create vector A
        A = self.Spatial(x)
        A = torch.reshape(A, (self.batch_size,self.channels_in))
        A = self.Linear(A)
        A = torch.reshape(A,(self.batch_size,1, self.K_conv_layers))

        # PROCESS 2: K number of stacked convolutional outputs
        to_be_stacked = []
        for i in range(self.K_conv_layers):

            out = self._modules['conv{0}'.format(i)](x)
            out = self._modules['relu{0}'.format(i)](out)
            out = self._modules['conv2{0}'.format(i)](out)
            out = self._modules['relu2{0}'.format(i)](out)
            out = self._modules['conv3{0}'.format(i)](out)
            out = self._modules['relu3{0}'.format(i)](out)
            to_be_stacked.append(out)

        # stack and flatten K number of convolutional outputs
        stack_K = torch.stack(to_be_stacked, dim=1)
        stack_K = self.flat2ndD(stack_K)
        # END of process 2. 

        # linear combination of the vector A and Stacked K number of 
        output = torch.matmul(A,stack_K)
        # reshape the combination for final steps in block
        output = torch.reshape(output,(self.batch_size,self.output_channels,self.input_dimensions,self.input_dimensions))
        
        # batch normalisation and max pooling
        output = self.batch(output)
        output = self.max_pool(output)
        return output

# %% [markdown]
# The Model Class takes a list of tuples.
# Each tuple represents the K number of convolutional outputs to be stacked, and the number of output channels/planes which the block will result in.
#
# Batch size is also passed into the model.
#
# After the final block has been run, **the model uses a 6 layer MLP for classification of the images:**
#
# - The classifer starts with an AdaptiveAvgPool2d which summarises the final feature map into a single value for each channel (inline with the specification).
#
# - Each layer in the classifer has 4096 perceptrons with the exception of the input (n=1024) and the output (n=10) layers.
#
# - Each layer has ReLU transformation and dropout layer.
#
# - SoftMax Regression is achieve by the use of CrossEntropyLoss

# %%
# the model which combines the blocks and classifies the dataset.

class Lotus_Model(nn.Module):

    def __init__(self, structure, batch_size):
        super(Lotus_Model, self).__init__()
        
        # 3 channels for an RGB image set
        in_channels = 3  
        #structure is the list of tuples (K_conv_layers, out_channels)
        self.structure = structure

        # run a number of blocks with the given structure
        for i, (K_conv_layers ,out_channels) in enumerate(self.structure):
          self.add_module('Lotus_Block{0}'.format(i), Lotus_Block(K_conv_layers, in_channels, out_channels, batch_size))
          in_channels = out_channels
        
        # The Classifer
        self.last = nn.Sequential(nn.AdaptiveAvgPool2d(output_size=1), nn.Flatten(), 
                                nn.Linear(out_channels, 4096), nn.ReLU(), nn.Dropout(0.5),
                                nn.Linear(4096, 4096), nn.ReLU(), nn.Dropout(0.5),
                                nn.Linear(4096, 4096), nn.ReLU(), nn.Dropout(0.5), 
                                nn.Linear(4096, 4096), nn.ReLU(), nn.Dropout(0.5), 
                                nn.Linear(4096, 4096), nn.ReLU(), nn.Dropout(0.5), 
                                nn.Linear(4096, 10))
      

    def forward(self, x):
        out = x

        # foward through the blocks
        for i in range(len(self.structure)):
            out = self._modules['Lotus_Block{0}'.format(i)](out)
        # forward through the classifier
        out = self.last(out)
        return out

# %% [markdown]
# Create the model and initialise it to the GPU.
#
# I have used Xavier_uniform to intialise the models weights.

# %%
structure = ((10, 96), (10, 256), (10, 512),  (10, 1024))
batch_size = 196

net = Lotus_Model(structure, batch_size)

# %%
def init_weights(m):
    if type(m) == nn.Linear or type(m) == nn.Conv2d : 
        torch.nn.init.xavier_uniform_(m.weight)   

net.to(device)
net.train()
net.apply(init_weights)
# Out:
# Lotus_Model(
#   (Lotus_Block0): Lotus_Block(
#     (Spatial): AdaptiveAvgPool2d(output_size=1)
#     (Linear): Linear(in_features=3, out_features=10, bias=True)
#     (NLactivation): ReLU()
#     (flat2ndD): Flatten(start_dim=2, end_dim=-1)
#     (conv0): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu0): ReLU()
#     (conv20): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu20): ReLU()
#     (conv30): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu30): ReLU()
#     (conv1): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu1): ReLU()
#     (conv21): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu21): ReLU()
#     (conv31): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu31): ReLU()
#     (conv2): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu2): ReLU()
#     (conv22): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu22): ReLU()
#     (conv32): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu32): ReLU()
#     (conv3): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu3): ReLU()
#     (conv23): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu23): ReLU()
#     (conv33): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu33): ReLU()
#     (conv4): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu4): ReLU()
#     (conv24): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu24): ReLU()
#     (conv34): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu34): ReLU()
#     (conv5): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu5): ReLU()
#     (conv25): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu25): ReLU()
#     (conv35): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu35): ReLU()
#     (conv6): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu6): ReLU()
#     (conv26): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu26): ReLU()
#     (conv36): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu36): ReLU()
#     (conv7): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu7): ReLU()
#     (conv27): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu27): ReLU()
#     (conv37): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu37): ReLU()
#     (conv8): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu8): ReLU()
#     (conv28): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu28): ReLU()
#     (conv38): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu38): ReLU()
#     (conv9): Conv2d(3, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu9): ReLU()
#     (conv29): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu29): ReLU()
#     (conv39): Conv2d(96, 96, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu39): ReLU()
#     (batch): BatchNorm2d(96, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Lotus_Block1): Lotus_Block(
#     (Spatial): AdaptiveAvgPool2d(output_size=1)
#     (Linear): Linear(in_features=96, out_features=10, bias=True)
#     (NLactivation): ReLU()
#     (flat2ndD): Flatten(start_dim=2, end_dim=-1)
#     (conv0): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu0): ReLU()
#     (conv20): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu20): ReLU()
#     (conv30): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu30): ReLU()
#     (conv1): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu1): ReLU()
#     (conv21): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu21): ReLU()
#     (conv31): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu31): ReLU()
#     (conv2): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu2): ReLU()
#     (conv22): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu22): ReLU()
#     (conv32): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu32): ReLU()
#     (conv3): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu3): ReLU()
#     (conv23): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu23): ReLU()
#     (conv33): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu33): ReLU()
#     (conv4): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu4): ReLU()
#     (conv24): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu24): ReLU()
#     (conv34): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu34): ReLU()
#     (conv5): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu5): ReLU()
#     (conv25): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu25): ReLU()
#     (conv35): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu35): ReLU()
#     (conv6): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu6): ReLU()
#     (conv26): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu26): ReLU()
#     (conv36): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu36): ReLU()
#     (conv7): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu7): ReLU()
#     (conv27): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu27): ReLU()
#     (conv37): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu37): ReLU()
#     (conv8): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu8): ReLU()
#     (conv28): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu28): ReLU()
#     (conv38): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu38): ReLU()
#     (conv9): Conv2d(96, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu9): ReLU()
#     (conv29): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu29): ReLU()
#     (conv39): Conv2d(256, 256, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu39): ReLU()
#     (batch): BatchNorm2d(256, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Lotus_Block2): Lotus_Block(
#     (Spatial): AdaptiveAvgPool2d(output_size=1)
#     (Linear): Linear(in_features=256, out_features=10, bias=True)
#     (NLactivation): ReLU()
#     (flat2ndD): Flatten(start_dim=2, end_dim=-1)
#     (conv0): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu0): ReLU()
#     (conv20): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu20): ReLU()
#     (conv30): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu30): ReLU()
#     (conv1): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu1): ReLU()
#     (conv21): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu21): ReLU()
#     (conv31): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu31): ReLU()
#     (conv2): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu2): ReLU()
#     (conv22): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu22): ReLU()
#     (conv32): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu32): ReLU()
#     (conv3): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu3): ReLU()
#     (conv23): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu23): ReLU()
#     (conv33): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu33): ReLU()
#     (conv4): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu4): ReLU()
#     (conv24): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu24): ReLU()
#     (conv34): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu34): ReLU()
#     (conv5): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu5): ReLU()
#     (conv25): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu25): ReLU()
#     (conv35): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu35): ReLU()
#     (conv6): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu6): ReLU()
#     (conv26): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu26): ReLU()
#     (conv36): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu36): ReLU()
#     (conv7): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu7): ReLU()
#     (conv27): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu27): ReLU()
#     (conv37): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu37): ReLU()
#     (conv8): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu8): ReLU()
#     (conv28): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu28): ReLU()
#     (conv38): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu38): ReLU()
#     (conv9): Conv2d(256, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu9): ReLU()
#     (conv29): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu29): ReLU()
#     (conv39): Conv2d(512, 512, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu39): ReLU()
#     (batch): BatchNorm2d(512, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (Lotus_Block3): Lotus_Block(
#     (Spatial): AdaptiveAvgPool2d(output_size=1)
#     (Linear): Linear(in_features=512, out_features=10, bias=True)
#     (NLactivation): ReLU()
#     (flat2ndD): Flatten(start_dim=2, end_dim=-1)
#     (conv0): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu0): ReLU()
#     (conv20): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu20): ReLU()
#     (conv30): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu30): ReLU()
#     (conv1): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu1): ReLU()
#     (conv21): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu21): ReLU()
#     (conv31): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu31): ReLU()
#     (conv2): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu2): ReLU()
#     (conv22): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu22): ReLU()
#     (conv32): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu32): ReLU()
#     (conv3): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu3): ReLU()
#     (conv23): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu23): ReLU()
#     (conv33): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu33): ReLU()
#     (conv4): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu4): ReLU()
#     (conv24): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu24): ReLU()
#     (conv34): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu34): ReLU()
#     (conv5): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu5): ReLU()
#     (conv25): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu25): ReLU()
#     (conv35): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu35): ReLU()
#     (conv6): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu6): ReLU()
#     (conv26): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu26): ReLU()
#     (conv36): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu36): ReLU()
#     (conv7): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu7): ReLU()
#     (conv27): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu27): ReLU()
#     (conv37): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu37): ReLU()
#     (conv8): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu8): ReLU()
#     (conv28): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu28): ReLU()
#     (conv38): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu38): ReLU()
#     (conv9): Conv2d(512, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu9): ReLU()
#     (conv29): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu29): ReLU()
#     (conv39): Conv2d(1024, 1024, kernel_size=(3, 3), stride=(1, 1), padding=(1, 1))
#     (relu39): ReLU()
#     (batch): BatchNorm2d(1024, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#     (max_pool): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   )
#   (last): Sequential(
#     (0): AdaptiveAvgPool2d(output_size=1)
#     (1): Flatten(start_dim=1, end_dim=-1)
#     (2): Linear(in_features=1024, out_features=4096, bias=True)
#     (3): ReLU()
#     (4): Dropout(p=0.5, inplace=False)
#     (5): Linear(in_features=4096, out_features=4096, bias=True)
#     (6): ReLU()
#     (7): Dropout(p=0.5, inplace=False)
#     (8): Linear(in_features=4096, out_features=4096, bias=True)
#     (9): ReLU()
#     (10): Dropout(p=0.5, inplace=False)
#     (11): Linear(in_features=4096, out_features=4096, bias=True)
#     (12): ReLU()
#     (13): Dropout(p=0.5, inplace=False)
#     (14): Linear(in_features=4096, out_features=4096, bias=True)
#     (15): ReLU()
#     (16): Dropout(p=0.5, inplace=False)
#     (17): Linear(in_features=4096, out_features=10, bias=True)
#   )
# )

# %% [markdown]
# Demonstrate that the model will produce 10 class predictions

# %%
a = torch.rand(196, 3, 32, 32)
a = a.to(device)
print(a.size())
out = net(a)
print(out.size())
# Out:
# torch.Size([196, 3, 32, 32])
# torch.Size([196, 10])

# %% [markdown]
# ## Section 3: Create the loss and the optimizer

# %% [markdown]
# I have used Cross Entropy Loss to as this will achieve the SoftMax regression classification required by the specification.

# %%
loss = nn.CrossEntropyLoss()

# %% [markdown]
# ## All the training details including hyper parameters used

# %% [markdown]
# The Optimizer has also undergone extensive experimentation to arrive at this final configuration.
#
# I have used a **momentum of 0.95** (0.9 and 0.99 produced non learning models in some cases and this felt most stable.)
#
# **Weight decay of 0.001** is well below "standard" values of 0.1 via experimentation I decided this gave some protection from over fitting while ensuring the model reaches a good maximum accuracy.
#
# **Learning rate and Training**
# The learning rate starts at 0.01
# The Optimizer is optim.SGD() with a MultiStepLR scheduler.
# The Scheduler drops the learning rate at epochs 270, 320, 340 by a factor of 0.1
#
# The training runs for 350 epochs in total.
#
# This results in a learning rate of:
# - 0.01 epochs 0-269
# - 0.001 epochs 270-319
# - 0.0001 epochs 320-339
# - 0.00001 epochs 340-350
#
# This schedule represents the end of result of squeezing the model to its limits.

# %%
lr = 0.01
num_epochs = 350
momentum = 0.95
weight_decay = 0.001

optimizer = torch.optim.SGD(net.parameters(), lr=lr, weight_decay=weight_decay, momentum=momentum,nesterov=False)

scheduler = torch.optim.lr_scheduler.MultiStepLR(optimizer, milestones=[  270,320,340,], gamma=0.1)

# %% [markdown]
# ## Section 4 Write the training script to train the model

# %% [markdown]
# I have modified code from the my_utilities.py and included it below.
#
# The animator shows the full loss and accuracy curves. I have also added a printout at each epoch giving the current epoch, train accuracy, test accuracy and loss.

# %%
def train_model_on_device(net, train_iter, test_iter, loss, num_epochs, optimizer, scheduler, device):  
    """
    based on my_utils.py with addition of scheduler, GPU device improvements to graphs 
    and text output each epoch
    
    net = the model to train
    train_iter = training batches
    test_iter = test batches
    loss = loss measure
    num_epochs = number of training rounds
    optimzer = the optimizer to train the model with
    scheduler = the learning rate scheduler
    device = the GPU device to train on 
    """
    animator = mu.Animator(xlabel='epoch', xlim=[1, num_epochs], ylim=[0.0, 2.5], 
                           legend=['train loss', 'train acc', 'test acc'], figsize=(10,8))
    for epoch in range(num_epochs):
        
        if isinstance(net, torch.nn.Module):
          net.train()
        # Sum of training loss, sum of training accuracy, no. of examples
        metric = mu.Accumulator(3)
        for X, y in train_iter:
            X, y = X.to(device), y.to(device)
            # Compute gradients and update parameters
            y_hat = net(X)
            l = loss(y_hat, y)
            if isinstance(optimizer, torch.optim.Optimizer):
                optimizer.zero_grad()
                l.backward()
                optimizer.step()
                metric.add(float(l) * len(y), mu.accuracy(y_hat, y),
                          y.size().numel())
            else:
                l.sum().backward()
                optimizer(X.shape[0])
                metric.add(float(l.sum()), mu.accuracy(y_hat, y), y.numel())
        # move the scheduler foward a step
        scheduler.step()

        # Return training loss and training accuracy
        train_metrics = metric[0] / metric[2], metric[1] / metric[2]
        test_acc = mu.evaluate_accuracy_gpu(net, test_iter)

        #output the results to monitor
        print("epoch: ",epoch)
        print("train_acc: ",train_metrics[1])
        print("test_acc: ",test_acc)
        print("loss: ",train_metrics[0])
        animator.add(epoch + 1, train_metrics + (test_acc,))

    
    #After training has finished 
    train_loss, train_acc = train_metrics
    assert train_loss < 0.5, train_loss
    assert train_acc <= 1 and train_acc > 0.7, train_acc
    assert test_acc <= 1 and test_acc > 0.7, test_acc
    print("epoch: ",epoch)
    print("final train_acc: ",train_metrics[1])
    print("final test_acc: ",test_acc)
    print("final loss: ",train_metrics[0])

# %% [markdown]
# ## Model training, loss and accuracy curves

# %% [markdown]
# NOTE: with a batch_size=192 this code will take around 18 hours to run and will require at least 40GB GPU (premium gpu on colab)
#
# To run this with a standard GPU use batch_size=64 . One epoch will run in around 25 minutes (this is not recommended)

# %%
train_model_on_device(net, train_iter, test_iter, loss, num_epochs, optimizer, scheduler, device)
# Out:
# epoch:  349
# final train_acc:  0.98434
# final test_acc:  0.9517
# final loss:  0.05018741971943527

# %% [markdown]
# ## Section 5: Final Model accuracy on CIFAR-10 valisation set

# %% [markdown]
# I now reload the CIFAR evaluation set in full and apply only the normalisation values taken from D2L.ai
#
# **The model has a final accuracy of 95.17%**

# %%
def get_dataloader_workers(): 
    """Use 4 processes to read the data."""
    return 4


def load_eval_cifar_10(batch_size, resize=None):  
    """Download the CIFAR_10 dataset and then load it into memory.
    normalisation values taken from https://d2l.ai/chapter_computer-vision/kaggle-cifar10.html
    """
    #normalisation only
    trans = [transforms.ToTensor(),transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010)) ]
    
    if resize:
        trans.insert(0, transforms.Resize(resize))
    trans = transforms.Compose(trans)
    torchvision.datasets.CIFAR10
    cifar_train = torchvision.datasets.CIFAR10(root="../data", train=True, transform=trans, download=True)
    cifar_test = torchvision.datasets.CIFAR10(root="../data", train=False, transform=trans, download=True)
    return (data.DataLoader(cifar_train, batch_size, shuffle=True,num_workers=get_dataloader_workers()),
            data.DataLoader(cifar_test, batch_size, shuffle=False,num_workers=get_dataloader_workers()))

# %%
batch_size = 196
resize = 56

_, eval_iter = load_eval_cifar_10(batch_size, resize=resize)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %%
net = net.eval()
evalulation = mu.evaluate_accuracy_gpu(net, eval_iter, device)
print(evalulation)
# Out:
# 0.9517

# %% [markdown]
# ## Appendix: Saved the model, and allow the model to be evaluated independently

# %% [markdown]
# Due to the time taken to train, I have created a copy of the model for independent evaluation.

# %% [markdown]
# This is the code to save the model

# %%
torch.save(net.state_dict(), "Lotus_model_LongRun.pkl")
torch.save(optimizer.state_dict(), "Lotus_optim_LongRun.pkl")

# %% [markdown]
# Load the evaluation set

# %%
def get_dataloader_workers(): 
    """Use 4 processes to read the data."""
    return 4


def load_eval_cifar_10(batch_size, resize=None):  
    """Download the CIFAR_10 dataset and then load it into memory.
    normalisation values taken from https://d2l.ai/chapter_computer-vision/kaggle-cifar10.html
    """
    #the most basic transformations
    trans = [transforms.ToTensor(),transforms.Normalize((0.4914, 0.4822, 0.4465),(0.2023, 0.1994, 0.2010)) ]
   
    if resize:
        trans.insert(0, transforms.Resize(resize))
    trans = transforms.Compose(trans)
    torchvision.datasets.CIFAR10
    cifar_train = torchvision.datasets.CIFAR10(root="../data", train=True, transform=trans, download=True)
    cifar_test = torchvision.datasets.CIFAR10(root="../data", train=False, transform=trans, download=True)
    return (data.DataLoader(cifar_train, batch_size, shuffle=True,num_workers=get_dataloader_workers()),
            data.DataLoader(cifar_test, batch_size, shuffle=False,num_workers=get_dataloader_workers()))

# %%
batch_size = 196
resize = 56
_, eval_iter = load_eval_cifar_10(batch_size, resize=resize)
# Out:
# Files already downloaded and verified
# Files already downloaded and verified

# %% [markdown]
# Create an instance of the model and upload the trained model state dictionary.
#
# You will need to upload the 'Lotus_model_LongRun.pkl' file to the local drive (This file is 1.5GB in size and is avaliable on request)

# %%
conv_arch = ((10, 96), (10, 256), (10, 512),(10, 1024) )
batch_size = 196

model = Lotus_Model(conv_arch, batch_size)
model.load_state_dict(torch.load('Lotus_model_LongRun.pkl'))
model.to(device)
model.eval()
evalulation = mu.evaluate_accuracy_gpu(model, eval_iter, device)
print(evalulation)
# Out:
# 0.9517

# %% [markdown]
# #Concluding notes
#
# I am very happy to have broken the 95% accuracy target given as a strech goal. Given the original images which are very small and the limitations of the specification, building this model has been a great challenge.
#
# The CIFAR-10 data set images are small, blurry and sometime difficult to classify without labels.
#
# The 10 classes include catergories that are very similiar in some cases. The dog and cat, dog and deer, deer and horse, bird and frog, truck and automobile classes have some cases which might trick humans without the class labels to choose from.
#
# I have named the final model "Lotus" as the lotus flower is famously beautiful and spotless despite growing in muddy water. It emerges from the mess it grows in.
#
#
# According to papers with code, https://paperswithcode.com/sota/image-classification-on-cifar-10
#
# My model would rank 125 in its list, achieving parity with state-of-the-art in 2019-2021.
#
# I think this is the greater achievement, that I've managed to reach this level with an original specification.
#
# According to Kaggle on medium in their interview with Yan LeCan https://medium.com/kaggle-blog/convolutional-nets-and-cifar-10-an-interview-with-yann-lecun-2ffe8f9ee3d6
# The human error rate on the CIFAR-10 data set is 6%. So it wouldn't be too much to say that the Lotus model has achieve human level abilities with this specific task.

# %% [markdown]
# ![Screenshot 2023-04-07 at 13.18.35.png](data:image/png;base64,...)

# %% [markdown]
# ![Screenshot 2023-04-07 at 13.17.57.png](data:image/png;base64,...)
